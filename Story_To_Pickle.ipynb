# %%
import pandas as pd
import numpy as np
data = pd.read_csv('dataset/cloze_test_val__spring2016 - cloze_test_ALL_val.csv', delimiter = ',',names=['InputStoryid','InputSentence1','InputSentence2','InputSentence3','InputSentence4','RandomFifthSentenceQuiz1','RandomFifthSentenceQuiz2','AnswerRightEnding'])

transformed_df1 = pd.DataFrame()
transformed_df1['correct'] = ((data['AnswerRightEnding'][1:]).astype(int)) - 1 
transformed_df1['sentences'] = data[['InputSentence1','InputSentence2','InputSentence3','InputSentence4']].apply(lambda x: '|'.join(x).split('|'), axis=1)
transformed_df1['candidates'] = data[['RandomFifthSentenceQuiz1','RandomFifthSentenceQuiz2']].apply(lambda x: '|'.join(x).split('|'), axis=1)
transformed_df1['entity'] = None
list1 = list(transformed_df1.T.to_dict().values())


data = pd.read_csv('dataset/cloze_test_test__spring2016 - cloze_test_ALL_test.csv', delimiter = ',',names=['InputStoryid','InputSentence1','InputSentence2','InputSentence3','InputSentence4','RandomFifthSentenceQuiz1','RandomFifthSentenceQuiz2','AnswerRightEnding'])
transformed_df2 = pd.DataFrame()
transformed_df2['correct'] = ((data['AnswerRightEnding'][1:]).astype(int)) - 1 
transformed_df2['sentences'] = data[['InputSentence1','InputSentence2','InputSentence3','InputSentence4']].apply(lambda x: '|'.join(x).split('|'), axis=1)
transformed_df2['candidates'] = data[['RandomFifthSentenceQuiz1','RandomFifthSentenceQuiz2']].apply(lambda x: '|'.join(x).split('|'), axis=1)
transformed_df2['entity'] = None
list2 = list(transformed_df2.T.to_dict().values())


data = pd.read_csv('dataset/cloze_test_val__winter2018-cloze_test_ALL_val - 1 - 1.csv', delimiter = ',',names=['InputStoryid','InputSentence1','InputSentence2','InputSentence3','InputSentence4','RandomFifthSentenceQuiz1','RandomFifthSentenceQuiz2','AnswerRightEnding'])
transformed_df3 = pd.DataFrame()
transformed_df3['correct'] = ((data['AnswerRightEnding'][1:]).astype(int)) - 1 
transformed_df3['sentences'] = data[['InputSentence1','InputSentence2','InputSentence3','InputSentence4']].apply(lambda x: '|'.join(x).split('|'), axis=1)
transformed_df3['candidates'] = data[['RandomFifthSentenceQuiz1','RandomFifthSentenceQuiz2']].apply(lambda x: '|'.join(x).split('|'), axis=1)
transformed_df3['entity'] = None
list3 = list(transformed_df3.T.to_dict().values())

from itertools import chain
transformed_df_dict = list(chain(list1,list2,list2))

print(transformed_df_dict)

# import pickle
# with open("./dataset/story_3training.pkl", 'wb') as f:
#     pickle.dump(transformed_df_dict, f)

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('dataset/cloze_test_val__spring2016 - cloze_test_ALL_val.csv', delimiter = ',',names=['InputStoryid','InputSentence1','InputSentence2','InputSentence3','InputSentence4','RandomFifthSentenceQuiz1','RandomFifthSentenceQuiz2','AnswerRightEnding'])

transformed_df = pd.DataFrame()
transformed_df['correct'] = ((data['AnswerRightEnding'][1:]).astype(int)) - 1 
transformed_df['sentences'] = data[['InputSentence1','InputSentence2','InputSentence3','InputSentence4']].apply(lambda x: '|'.join(x).split('|'), axis=1)
transformed_df['candidates'] = data[['RandomFifthSentenceQuiz1','RandomFifthSentenceQuiz2']].apply(lambda x: '|'.join(x).split('|'), axis=1)
transformed_df['entity'] = None
transformed_df_dict = list(transformed_df.T.to_dict().values())

import pickle
with open("./dataset/story_spring_val.pkl", 'wb') as f:
    pickle.dump(transformed_df_dict, f)

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('dataset/cloze_test_test__spring2016 - cloze_test_ALL_test.csv', delimiter = ',',names=['InputStoryid','InputSentence1','InputSentence2','InputSentence3','InputSentence4','RandomFifthSentenceQuiz1','RandomFifthSentenceQuiz2','AnswerRightEnding'])

transformed_df = pd.DataFrame()
transformed_df['correct'] = ((data['AnswerRightEnding'][1:]).astype(int)) - 1 
transformed_df['sentences'] = data[['InputSentence1','InputSentence2','InputSentence3','InputSentence4']].apply(lambda x: '|'.join(x).split('|'), axis=1)
transformed_df['candidates'] = data[['RandomFifthSentenceQuiz1','RandomFifthSentenceQuiz2']].apply(lambda x: '|'.join(x).split('|'), axis=1)
transformed_df['entity'] = None
transformed_df_dict = list(transformed_df.T.to_dict().values())

import pickle
with open("./dataset/story_spring_test.pkl", 'wb') as f:
    pickle.dump(transformed_df_dict, f)

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('dataset/cloze_test_val__winter2018-cloze_test_ALL_val - 1 - 1.csv', delimiter = ',',names=['InputStoryid','InputSentence1','InputSentence2','InputSentence3','InputSentence4','RandomFifthSentenceQuiz1','RandomFifthSentenceQuiz2','AnswerRightEnding'])
print(data)
transformed_df = pd.DataFrame()
transformed_df['correct'] = ((data['AnswerRightEnding'][1:]).astype(int)) - 1 
transformed_df['sentences'] = data[['InputSentence1','InputSentence2','InputSentence3','InputSentence4']].apply(lambda x: '|'.join(x).split('|'), axis=1)
transformed_df['candidates'] = data[['RandomFifthSentenceQuiz1','RandomFifthSentenceQuiz2']].apply(lambda x: '|'.join(x).split('|'), axis=1)
transformed_df['entity'] = None
transformed_df_dict = list(transformed_df.T.to_dict().values())

import pickle
with open("./dataset/story_winter_val.pkl", 'wb') as f:
    pickle.dump(transformed_df_dict, f)
# Out:
#                               InputStoryid  \
# 0                             InputStoryid
# 1     138d5bfb-05cc-41e3-bf2c-fa85ebad14e2
# 2     bff9f820-9605-4875-b9af-fe6f14d04256
# 3     e8f628d5-9f97-40ed-8611-fc0e774673c4
# 4     f5226bfe-9f26-4377-b05f-3d9568dbdec1
# 5     69ac9b05-b956-402f-9fff-1f926ef9176b
# 6     d80cabdd-7a85-47e3-86be-5ce6591ca51e
# 7     58090d3f-8a91-4c89-83ef-2b4994de9d24
# 8     e17053ac-2046-48c8-a7a2-7b9509c10e64
# 9     69b26ae4-b778-4cd1-9f13-27d28fd4430e
# 10    1f7d9fa2-2191-49de-bdd1-7d307293b9e0
# 11    a7905e16-15be-433f-bdef-b488a83e4582
# 12    52dbbfda-5b42-4ace-8d59-55cee3eb30c0
# 13    1edf348d-6fce-4ea3-937c-28ade02f28b8
# 14    0fe46de6-6ee3-4932-a578-268917372566
# 15    625d1e13-8bd3-40b3-ac45-0b16a549fc69
# 16    aa615e4f-83c1-4b65-96a4-6a989d253a52
# 17    fa0d318c-d286-4c8e-adda-c2590f100f02
# 18    501c6884-8885-4df3-ae8c-f3f9328fde54
# 19    8d9f72c4-7f31-4e86-8511-e921fd8f78bb
# 20    ba87797c-dc31-402b-8740-d30c093d4df7
# ...

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('dataset/cloze_test_test__winter2018-cloze_test_ALL_test - 1.csv', delimiter = ',',names=['InputStoryid','InputSentence1','InputSentence2','InputSentence3','InputSentence4','RandomFifthSentenceQuiz1','RandomFifthSentenceQuiz2','AnswerRightEnding'])
print(data)
transformed_df = pd.DataFrame()
transformed_df['correct'] = data['AnswerRightEnding'][1:]
transformed_df['correct'] =2
transformed_df['sentences'] = data[['InputSentence1','InputSentence2','InputSentence3','InputSentence4']].apply(lambda x: '|'.join(x).split('|'), axis=1)
transformed_df['candidates'] = data[['RandomFifthSentenceQuiz1','RandomFifthSentenceQuiz2']].apply(lambda x: '|'.join(x).split('|'), axis=1)
transformed_df['entity'] = None
transformed_df_dict = list(transformed_df.T.to_dict().values())

import pickle
with open("./dataset/story_winter_test.pkl", 'wb') as f:
    pickle.dump(transformed_df_dict, f)
# Out:
#                               InputStoryid  \
# 0                             InputStoryid
# 1     f6aad64a-e34c-415d-b895-dbfa187ed43e
# 2     0fedd90d-5295-4b79-b2d0-15a2bad624ee
# 3     018152fd-f984-4d05-ad1e-12f1fb7eceb6
# 4     feef76df-b75a-4501-9c1a-f8a7b6ee442f
# 5     929eaf8b-a175-4460-a885-43be8a89ca62
# 6     e65dec15-d9db-4369-a048-ca25046aea1a
# 7     bcce5b73-0c0a-4de9-9f0b-29b64d2055a5
# 8     f07443b5-fece-45e3-8df4-92e5dd9898ca
# 9     144f8b43-563a-44b1-b137-1b1e07e3752f
# 10    2d45cd59-7c98-4fdf-b0a8-fa6abe745876
# 11    940388e1-1d00-4cc2-b6fc-3e4a56aa9c70
# 12    38225711-dd12-4676-935e-bfef8d2ac2e8
# 13    1fb7be7c-b222-448b-b368-4ccd0d21695a
# 14    2d519d87-9522-4e51-9f99-5330ebe001f6
# 15    b9cf0628-9ee9-4245-b5a0-fe3a816a67d8
# 16    7fc6c821-3f4e-414b-88b2-5b72a7edd1cb
# 17    27954a1d-96c2-4d10-ba3c-766f9596aa5e
# 18    aa9b53d2-3c47-4393-a059-9ef59c19efa5
# 19    c618bb30-f191-416e-9e84-35e0af74457f
# 20    0f20b37e-bb84-4373-a3ae-e7c2e4243b1c
# ...
